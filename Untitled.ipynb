# %%
from matplotlib import pyplot as plt 
import binascii
import cv2
import os
import sys
from pathlib import Path

from dataset_helper import dataset_iterators
# Out:
# /mnt/HDD/home/aditya/DatasetPipeline/dataset

# %%
phone_iter = dataset_iterators.AndroidDatasetIterator()
phone_iter
# Out:
# Init path: /mnt/HDD/home/aditya/DatasetPipeline/dataset/android/calibration
# ----------------------------------------------------
# AndroidDatasetIterator('/mnt/HDD/home/aditya/DatasetPipeline/dataset/android/calibration')
# ----------------------------------------------------
# self.fps:			26.647270882817207
# self.frame_count:	2475
# self.start_time_csv:	2022-06-06 18:27:15.961000
# self.end_time_csv:	2022-06-06 18:28:50.167000
# self.expected_duration:	0:01:34.206000
# self.expected_fps:	26.27221196102159
# self.csv_fps:			9.967517992484554
# ----------------------------------------------------

# %%
for i in range(0, len(phone_iter), 5):
	phone_data, phone_frame = phone_iter[i]
	cv2.imwrite("calibration/pocoX3/raw/"+str(i)+".png", phone_frame)
# Out:
# cap.set:  2476
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  13
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  13
# cap.set:  14
# cap.set:  13
# cap.set:  13
# ...
